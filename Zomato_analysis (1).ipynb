# %%
import pandas as pd

# %%
zomato = pd.read_csv("D:/DATAset/Zomato_Dataset.csv")

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
zomato.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
zomato.shape
# Out:
# (45584, 20)

# %% [markdown]
# # Missing null value

# %%
MEDIAN_Delivery_person_Age = zomato['Delivery_person_Age'].median()
print(MEDIAN_Delivery_person_Age)
# Out:
# 30.0

# %%
zomato['Delivery_person_Age'] = zomato['Delivery_person_Age'].fillna(MEDIAN_Delivery_person_Age)

# %% [markdown]
# # Ratings

# %%
MEDIAN_Delivery_person_Ratings = zomato['Delivery_person_Ratings'].median()
zomato['Delivery_person_Ratings'].fillna(MEDIAN_Delivery_person_Ratings, inplace = True)

# %% [markdown]
# # Weather conditions

# %%
zomato['Weather_conditions'].value_counts()
# Out:
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: Weather_conditions, dtype: int64

# %%
zomato['Weather_conditions'].fillna('Sunny', inplace = True)
zomato['Weather_conditions'].value_counts()
# Out:
# Sunny         7898
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Name: Weather_conditions, dtype: int64

# %% [markdown]
# # Road traffic density

# %%
zomato['Road_traffic_density'].value_counts()
# Out:
# Low       15476
# Jam       14139
# Medium    10945
# High       4423
# Name: Road_traffic_density, dtype: int64

# %%
zomato['Road_traffic_density'].fillna('Low', inplace = True)

# %% [markdown]
# # Multiple Deliveries

# %%
zomato['multiple_deliveries'].value_counts()
# Out:
# 1.0    28151
# 0.0    14094
# 2.0     1985
# 3.0      361
# Name: multiple_deliveries, dtype: int64

# %%
zomato[zomato['multiple_deliveries'] == 0.0]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 3      0xc8b6     LUDHRES15DEL02                 34.0
# 11     0x5795   RANCHIRES06DEL02                 31.0
# 16     0x3231      JAPRES16DEL03                 27.0
# 17     0x8bc0      SURRES15DEL03                 35.0
# 19     0x3c5e     PUNERES04DEL01                 23.0
# ...       ...                ...                  ...
# 45565  0x90c5      MUMRES20DEL03                 21.0
# 45573  0x59ae     PUNERES13DEL02                 30.0
# 45575  0xa333     CHENRES08DEL02                 37.0
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 3                          4.3            30.899584             75.809346
# 11                         4.7            23.357804             85.325146
# 16                         5.0            26.849596             75.800512
# 17                         4.3            21.160522             72.771477
# 19                         4.8            18.514210             73.838429
# ...                        ...                  ...                   ...
# 45565                      4.8            19.103249             72.846749
# 45573                      4.6            18.562450             73.916619
# 45575                      4.8            13.022394             80.242439
# 45579                      4.8            26.902328             75.794257
# 45581                      4.9            13.022394             80.242439
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 3                       30.919584                    75.829346  13-02-2022
# 11                      23.487804                    85.455146  10-03-2022
# 16                      26.879596                    75.830512  05-04-2022
# 17                      21.250522                    72.861477  12-03-2022
# 19                      18.624210                    73.948429  02-04-2022
# ...                           ...                          ...         ...
# 45565                   19.133249                    72.876749  19-03-2022
# 45573                   18.582450                    73.936619  01-04-2022
# 45575                   13.042394                    80.262439  05-04-2022
# 45579                   26.912328                    75.804257  24-03-2022
# 45581                   13.052394                    80.272439  11-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 3           09:20             09:30         Sandstorms                  Low
# 11          22:30             22:45         Sandstorms                  Low
# 16          20:35             20:40             Stormy                  Jam
# 17          23:20             23:30             Cloudy                  Low
# 19          23:35             23:45              Windy                  Low
# ...           ...               ...                ...                  ...
# 45565       22:15             22:20              Sunny                  Low
# 45573       0.375             09:15             Cloudy                  Low
# 45575       09:35             09:50         Sandstorms                  Low
# 45579       11:35             11:45              Windy                 High
# 45581       23:50          24:05:00             Cloudy                  Low
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries  \
# 3                      0        Buffet        motorcycle                  0.0
# 11                     2          Meal  electric_scooter                  0.0
# 16                     0         Snack        motorcycle                  0.0
# 17                     1        Drinks           scooter                  0.0
# 19                     2        Buffet  electric_scooter                  0.0
# ...                  ...           ...               ...                  ...
# 45565                  2        Drinks        motorcycle                  0.0
# 45573                  0          Meal        motorcycle                  0.0
# 45575                  2        Drinks  electric_scooter                  0.0
# 45579                  1          Meal        motorcycle                  0.0
# 45581                  1        Drinks           scooter                  0.0
#
#       Festival           City  Time_taken (min)
# 3           No  Metropolitian                20
# 11          No  Metropolitian                26
# 16          No          Urban                18
# 17          No  Metropolitian                38
# 19          No          Urban                12
# ...        ...            ...               ...
# 45565       No  Metropolitian                22
# 45573       No  Metropolitian                20
# 45575       No  Metropolitian                20
# 45579       No  Metropolitian                32
# 45581       No  Metropolitian                16
#
# [14094 rows x 20 columns]

# %%
zomato['multiple_deliveries'].replace({0.0:1.0}, inplace = True)

# %%
zomato['multiple_deliveries'] = zomato['multiple_deliveries'].fillna(1, inplace = True)

# %% [markdown]
# # Festivals

# %%
zomato['Festival'].value_counts()
# Out:
# No     44460
# Yes      896
# Name: Festival, dtype: int64

# %% [markdown]
# # Mode

# %%
zomato['Festival'].mode()
# Out:
# 0    No
# Name: Festival, dtype: object

# %%
Festival_mode = zomato['Festival'].mode()[0]
zomato['Festival'].fillna(Festival_mode, inplace = True)

# %%
zomato['Festival'].value_counts()
# Out:
# No     44688
# Yes      896
# Name: Festival, dtype: int64

# %% [markdown]
# # City

# %%
zomato['City'].value_counts()
# Out:
# Metropolitian    34087
# Urban            10133
# Semi-Urban         164
# Name: City, dtype: int64

# %%
City_mode = zomato['City'].mode()[0]
zomato['City'] = zomato['City'].fillna(City_mode)

# %%
zomato.isnull().sum()
# Out:
# ID                                 0
# Delivery_person_ID                 0
# Delivery_person_Age                0
# Delivery_person_Ratings            0
# Restaurant_latitude                0
# Restaurant_longitude               0
# Delivery_location_latitude         0
# Delivery_location_longitude        0
# Order_Date                         0
# Time_Orderd                     1731
# Time_Order_picked                  0
# Weather_conditions                 0
# Road_traffic_density               0
# Vehicle_condition                  0
# Type_of_order                      0
# Type_of_vehicle                    0
# multiple_deliveries            45584
# Festival                           0
# City                               0
# Time_taken (min)                   0
# dtype: int64

# %% [markdown]
# # Time ordered

# %%
'09:20'.split(':')
# Out:
# ['09', '20']

# %%
def time_window(time_ordered):
    try:
        hour = int(time_ordered.split(':')[0])
    except:
        return 'Not defined'
        
    
    if hour>= 7 and hour<=12:
        return 'morning'
    elif hour>= 4 and hour< 7:
        return 'early morning'
    elif hour>12 and hour<=17:
        return 'afternoon'
    elif hour >17 and hour<= 22:
        return 'evening'
    elif hour> 22 and hour<=24:
        return 'late evening'
    elif hour>= 0 and hour<4:
        return 'late evening'

# %%
time_window('16:00')
# Out:
# 'afternoon'

# %%
time_window('4:00')
# Out:
# 'early morning'

# %%
time_window('0.2')
# Out:
# 'Not defined'

# %%
zomato['Time_Orderd'] = zomato['Time_Orderd'].apply(time_window)

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022     evening             22:10
# 1                    76.347589  13-02-2022   afternoon             15:05
# 2                    74.006619  04-03-2022   afternoon             17:40
# 3                    75.829346  13-02-2022     morning             09:30
# 4                    80.502929  14-02-2022     evening             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City  \
# 0      motorcycle                None       No  Metropolitian
# 1      motorcycle                None       No  Metropolitian
# 2         scooter                None       No  Metropolitian
# 3      motorcycle                None       No  Metropolitian
# 4         scooter                None       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
zomato['Time_Orderd'].value_counts()
# Out:
# evening         20783
# morning          7838
# afternoon        7075
# Not defined      5369
# late evening     4519
# Name: Time_Orderd, dtype: int64

# %%
from geopy.distance import geodesic

# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\hp\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\hp\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
from geopy.distance import geodesic

# %%
zomato.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
def distance(each_row):
    restaurant_loc = (each_row['Restaurant_latitude'], each_row['Restaurant_longitude'])
    delivery_loc = (each_row['Delivery_location_latitude'], each_row['Delivery_location_longitude'])
    return geodesic(restaurant_loc, delivery_loc).kilometers

zomato['distance_km'] = zomato.apply(distance, axis=1)

# %%
zomato.head(5)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# 0                    78.116106  12-02-2022     evening  ...
# 1                    76.347589  13-02-2022   afternoon  ...
# 2                    74.006619  04-03-2022   afternoon  ...
# 3                    75.829346  13-02-2022     morning  ...
# 4                    80.502929  14-02-2022     evening  ...
#
#   Weather_conditions Road_traffic_density Vehicle_condition  Type_of_order  \
# 0                Fog                  Jam                 2          Snack
# 1             Stormy                 High                 1           Meal
# 2         Sandstorms               Medium                 1         Drinks
# 3         Sandstorms                  Low                 0         Buffet
# 4                Fog                  Jam                 1          Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City  \
# 0      motorcycle                None       No  Metropolitian
# 1      motorcycle                None       No  Metropolitian
# 2         scooter                None       No  Metropolitian
# 3      motorcycle                None       No  Metropolitian
# 4         scooter                None       No  Metropolitian
#
#   Time_taken (min)  distance_km
# 0               46    10.271464
# 1               23     6.229376
# 2               21    13.764306
# 3               20     2.927795
# 4               41    19.373484
#
# [5 rows x 21 columns]

# %%
length = len(zomato)

for i  in range(0,length):
    restaurant_loc = (zomato.loc[i,'Restaurant_latitude'], zomato.loc[i,'Restaurant_longitude'])
    delivery_loc = (zomato.loc[i,'Delivery_location_latitude'], zomato.loc[i,'Delivery_location_longitude'])
    
    zomato.loc[i,'new_distance_km']= geodesic(restaurant_loc, delivery_loc).kilometers

# %%
zomato.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ...  \
# 0                    78.116106  12-02-2022     evening  ...
# 1                    76.347589  13-02-2022   afternoon  ...
# 2                    74.006619  04-03-2022   afternoon  ...
# 3                    75.829346  13-02-2022     morning  ...
# 4                    80.502929  14-02-2022     evening  ...
#
#   Road_traffic_density Vehicle_condition Type_of_order  Type_of_vehicle  \
# 0                  Jam                 2         Snack       motorcycle
# 1                 High                 1          Meal       motorcycle
# 2               Medium                 1        Drinks          scooter
# 3                  Low                 0        Buffet       motorcycle
# 4                  Jam                 1         Snack          scooter
#
#   multiple_deliveries Festival           City Time_taken (min) distance_km  \
# 0                None       No  Metropolitian               46   10.271464
# 1                None       No  Metropolitian               23    6.229376
# 2                None       No  Metropolitian               21   13.764306
# 3                None       No  Metropolitian               20    2.927795
# 4                None       No  Metropolitian               41   19.373484
#
#    new_distance_km
# 0        10.271464
# 1         6.229376
# 2        13.764306
# 3         2.927795
# 4        19.373484
#
# [5 rows x 22 columns]

# %%
zomato.drop(['ID','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude', 'Delivery_location_latitude','Delivery_location_longitude','Order_Date','Time_Order_picked','new_distance_km'], 
            axis = 1, inplace = True)

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City  \
# 0      motorcycle                None       No  Metropolitian
# 1      motorcycle                None       No  Metropolitian
# 2         scooter                None       No  Metropolitian
# 3      motorcycle                None       No  Metropolitian
# 4         scooter                None       No  Metropolitian
#
#    Time_taken (min)  distance_km
# 0                46    10.271464
# 1                23     6.229376
# 2                21    13.764306
# 3                20     2.927795
# 4                41    19.373484

# %% [markdown]
# # Descriptive Analysis

# %%
zomato.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Vehicle_condition  \
# count         45584.000000             45584.000000       45584.000000
# mean             29.584525                 4.636546           1.023385
# std               5.696221                 0.327931           0.839055
# min              15.000000                 1.000000           0.000000
# 25%              25.000000                 4.600000           0.000000
# 50%              30.000000                 4.700000           1.000000
# 75%              34.000000                 4.800000           2.000000
# max              50.000000                 6.000000           3.000000
#
#        Time_taken (min)   distance_km
# count      45584.000000  45584.000000
# mean          26.293963     99.216342
# std            9.384298   1100.033036
# min           10.000000      1.463837
# 25%           19.000000      4.654185
# 50%           26.000000      9.247098
# 75%           32.000000     13.740932
# max           54.000000  19709.575543

# %%
zomato['Weather_conditions'].value_counts()
# Out:
# Sunny         7898
# Fog           7653
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Name: Weather_conditions, dtype: int64

# %%
zomato['Type_of_vehicle'].value_counts(normalize = True)
# Out:
# motorcycle          0.579787
# scooter             0.335052
# electric_scooter    0.083670
# bicycle             0.001492
# Name: Type_of_vehicle, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(zomato['Delivery_person_Age'], kde = True )
plt.show()

# %%
zomato['age_bin'] = pd.cut(zomato['Delivery_person_Age'],bins = [18,26,33,40,50])

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City  \
# 0      motorcycle                None       No  Metropolitian
# 1      motorcycle                None       No  Metropolitian
# 2         scooter                None       No  Metropolitian
# 3      motorcycle                None       No  Metropolitian
# 4         scooter                None       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
zomato['age_bin'].value_counts()
# Out:
# (26, 33]    17107
# (18, 26]    15112
# (33, 40]    13274
# (40, 50]       53
# Name: age_bin, dtype: int64

# %%
sns.displot(zomato['distance_km'], kde = True )
plt.show()

# %%
zomato['distance_km'].max()
# Out:
# 19709.57554316093

# %%
distance_km_median = zomato['distance_km'].median()
distance_km_median
# Out:
# 9.24709793542702

# %%
zomato=  zomato[zomato['distance_km']<= 100]

# %%
sns.displot(zomato['distance_km'], kde = True )
plt.show()

# %%
zomato['distance_km'].min()
# Out:
# 1.4638371061422368

# %%
zomato['distance_km'].max()
# Out:
# 20.94290627698551

# %% [markdown]
# # Time taken

# %%
sns.displot(zomato['Time_taken (min)'], kde = True )
plt.show()

# %% [markdown]
# # Ratings

# %%
sns.displot(zomato['Delivery_person_Ratings'], kde = True )
plt.show()

# %% [markdown]
# # Countplot

# %%
sns.countplot(x = 'Time_Orderd', data = zomato)
plt.show()

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City  \
# 0      motorcycle                None       No  Metropolitian
# 1      motorcycle                None       No  Metropolitian
# 2         scooter                None       No  Metropolitian
# 3      motorcycle                None       No  Metropolitian
# 4         scooter                None       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
sns.countplot(x = 'Vehicle_condition', data = zomato)
plt.show()

# %%
sns.boxplot(zomato['distance_km'])
plt.show()

# %%
sns.boxplot(zomato['Time_taken (min)'])
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City  \
# 0      motorcycle                None       No  Metropolitian
# 1      motorcycle                None       No  Metropolitian
# 2         scooter                None       No  Metropolitian
# 3      motorcycle                None       No  Metropolitian
# 4         scooter                None       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
sns.scatterplot(x = 'distance_km', y = 'Time_taken (min)', data = zomato)
plt.show()

# %%
sns.scatterplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', data = zomato)
plt.show()

# %%
sns.boxplot(x = 'Time_Orderd', y = 'Time_taken (min)',data = zomato)
plt.show()

# %%
sns.boxplot(x = 'Road_traffic_density', y = 'Time_taken (min)',data = zomato)
plt.show()

# %%
sns.stripplot(x= 'age_bin', y = 'Time_taken (min)',data = zomato)
plt.show()

# %%
sns.heatmap(zomato.corr(numeric_only = True) ,annot=True)
plt.show()

# %% [markdown]
# # Multivariate analysis

# %%
zomato.head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Time_Orderd  \
# 0                 36.0                      4.2     evening
# 1                 21.0                      4.7   afternoon
# 2                 23.0                      4.7   afternoon
# 3                 34.0                      4.3     morning
# 4                 24.0                      4.7     evening
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle multiple_deliveries Festival           City  \
# 0      motorcycle                None       No  Metropolitian
# 1      motorcycle                None       No  Metropolitian
# 2         scooter                None       No  Metropolitian
# 3      motorcycle                None       No  Metropolitian
# 4         scooter                None       No  Metropolitian
#
#    Time_taken (min)  distance_km   age_bin
# 0                46    10.271464  (33, 40]
# 1                23     6.229376  (18, 26]
# 2                21    13.764306  (18, 26]
# 3                20     2.927795  (33, 40]
# 4                41    19.373484  (18, 26]

# %%
plt.figure(figsize= (8,8))
sns.scatterplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' ,data = zomato)
plt.show()

# %%
sns.boxplot(x = 'multiple_deliveries', y = 'Time_taken (min)',hue = 'Vehicle_condition',data = zomato)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\categorical.py:761: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(-.5, len(self.plot_data) - .5, auto=None)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot(x = 'multiple_deliveries', y = 'Delivery_person_Ratings',hue = 'Vehicle_condition',data = zomato)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\categorical.py:761: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(-.5, len(self.plot_data) - .5, auto=None)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize= (8,8))
sns.lmplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' , row = 'Road_traffic_density',data = zomato)
plt.show()

# %%
plt.figure(figsize= (8,12))
sns.lmplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' , row = 'Road_traffic_density', col= 'multiple_deliveries' , data = zomato)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 2
#       1 plt.figure(figsize= (8,12))
# ----> 2 sns.lmplot(y = 'Delivery_person_Ratings', x = 'Time_taken (min)', hue = 'Weather_conditions' , row = 'Road_traffic_density', col= 'multiple_deliveries' , data = zomato)
#       3 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\regression.py:598, in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     595 data = data[cols]
#     597 # Initialize the grid
# --> 598 facets = FacetGrid(
#     599     data, row=row, col=col, hue=hue,
#     600     palette=palette,
#     601     row_order=row_order, col_order=col_order, hue_order=hue_order,
#     602     height=height, aspect=aspect, col_wrap=col_wrap,
#     603     **facet_kws,
#     604 )
#     606 # Add the markers here as FacetGrid has figured out how many levels of the
#     607 # hue variable are needed and we don't want to duplicate that process
#     608 if facets.hue_names is None:
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:456, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     449 if col_wrap is None:
#     451     kwargs = dict(squeeze=False,
#     452                   sharex=sharex, sharey=sharey,
#     453                   subplot_kw=subplot_kws,
#     454                   gridspec_kw=gridspec_kws)
# --> 456     axes = fig.subplots(nrow, ncol, **kwargs)
#     458     if col is None and row is None:
#     459         axes_dict = {}
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:891, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     887         raise ValueError("'width_ratios' must not be defined both as "
#     888                          "parameter and as key in 'gridspec_kw'")
#     889     gridspec_kw['width_ratios'] = width_ratios
# --> 891 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     892 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     893                   subplot_kw=subplot_kw)
#     894 return axs
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:1514, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1475 """
#    1476 Return a `.GridSpec` that has this figure as a parent.  This allows
#    1477 complex layout of Axes in the figure.
#    (...)
#    1510
#    1511 """
#    1513 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1514 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1515 return gs
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:379, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     376 self.hspace = hspace
#     377 self.figure = figure
# --> 379 super().__init__(nrows, ncols,
#     380                  width_ratios=width_ratios,
#     381                  height_ratios=height_ratios)
#
# File ~\anaconda3\lib\site-packages\matplotlib\gridspec.py:52, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      49     raise ValueError(
#      50         f"Number of rows must be a positive integer, not {nrows!r}")
#      51 if not isinstance(ncols, Integral) or ncols <= 0:
# ---> 52     raise ValueError(
#      53         f"Number of columns must be a positive integer, not {ncols!r}")
#      54 self._nrows, self._ncols = nrows, ncols
#      55 self.set_height_ratios(height_ratios)
#
# ValueError: Number of columns must be a positive integer, not 0

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 8)) 


sns.scatterplot(x= 'Delivery_person_Ratings', y= 'Time_taken (min)', data=zomato, ax=axes[0, 0])
sns.boxplot(x= 'Vehicle_condition', y= 'Time_taken (min)', data=zomato, ax=axes[0, 1])
sns.boxplot(x= 'multiple_deliveries', y= 'Time_taken (min)', data=zomato, ax=axes[1, 0])
sns.boxplot(x='Type_of_order', y='Time_taken (min)', data=zomato, ax=axes[1, 1])
sns.boxplot(x='age_bin', y='Time_taken (min)', data=zomato, ax=axes[2, 0])
sns.scatterplot(x = 'distance_km', y = 'Time_taken (min)', data = zomato, ax=axes[2, 1])




axes[0, 0].set_title('Delivery_person_Ratings')
axes[0, 1].set_title('Vehicle_condition')
axes[1, 0].set_title('multiple_deliveries')
axes[1, 1].set_title('Type_of_order')
axes[2, 0].set_title('age_bin')
axes[2, 0].set_title('distance_km')




for ax in axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)




plt.tight_layout()


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 6
#       4 sns.scatterplot(x= 'Delivery_person_Ratings', y= 'Time_taken (min)', data=zomato, ax=axes[0, 0])
#       5 sns.boxplot(x= 'Vehicle_condition', y= 'Time_taken (min)', data=zomato, ax=axes[0, 1])
# ----> 6 sns.boxplot(x= 'multiple_deliveries', y= 'Time_taken (min)', data=zomato, ax=axes[1, 0])
#       7 sns.boxplot(x='Type_of_order', y='Time_taken (min)', data=zomato, ax=axes[1, 1])
#       8 sns.boxplot(x='age_bin', y='Time_taken (min)', data=zomato, ax=axes[2, 0])
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2231, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2224 def boxplot(
#    2225     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2226     orient=None, color=None, palette=None, saturation=.75, width=.8,
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2235     if ax is None:
#    2236         ax = plt.gca()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:786, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781 def __init__(self, x, y, hue, data, order, hue_order,
#     782              orient, color, palette, saturation,
#     783              width, dodge, fliersize, linewidth):
#     785     self.establish_variables(x, y, hue, data, orient, order, hue_order)
# --> 786     self.establish_colors(color, palette, saturation)
#     788     self.dodge = dodge
#     789     self.width = width
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:707, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     705 # Determine the gray color to use for the lines framing the plot
#     706 light_vals = [rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 707 lum = min(light_vals) * .6
#     708 gray = mpl.colors.rgb2hex((lum, lum, lum))
#     710 # Assign object attributes
#
# ValueError: min() arg is an empty sequence
